# %%
import pandas as pd
df = pd.read_csv('cleaned_online_retail.csv',encoding = 'latin1')
df.head()
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                  WHITE METAL LANTERN         6
# 2     536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#            InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice
# 0  2010-12-01 08:26:00       2.55     17850.0  United Kingdom       15.30
# 1  2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 2  2010-12-01 08:26:00       2.75     17850.0  United Kingdom       22.00
# 3  2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 4  2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34

# %%
df['Quantity'].describe()
# Out:
# count    299540.000000
# mean         10.394258
# std         203.238326
# min           1.000000
# 25%           2.000000
# 50%           4.000000
# 75%          10.000000
# max       80995.000000
# Name: Quantity, dtype: float64

# %%
df[df['Quantity']>1000]
# Out:
#         InvoiceNo StockCode                          Description  Quantity  \
# 2920       536830     21915               RED  HARMONICA IN BOX       1400
# 8581       537659     22189              CREAM HEART CARD HOLDER      1008
# 8582       537659     22188              BLACK HEART CARD HOLDER      1008
# 10355      537899     22328   ROUND SNACK BOXES SET OF 4 FRUITS       1488
# 25331      540689    85123A   WHITE HANGING HEART T-LIGHT HOLDER      1010
# 25332      540689     22469                HEART OF WICKER SMALL      1356
# 25333      540689     22470                HEART OF WICKER LARGE      1284
# 25754      540815    85123A   WHITE HANGING HEART T-LIGHT HOLDER      1930
# 25755      540815     21175          GIN + TONIC DIET METAL SIGN      2000
# 25756      540815     21108   FAIRY CAKE FLANNEL ASSORTED COLOUR      3114
# 25804      540818    47556B                 TEA TIME TEA TOWELS       1300
# ...

# %% [markdown]
# Explore >1000 Quantity records.

# %%
df[df['Quantity']<0]
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country, TotalPrice]
# Index: []

# %% [markdown]
# Check for negative Quantity. Not present.

# %%
df[df['UnitPrice']<0]
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country, TotalPrice]
# Index: []

# %% [markdown]
# Check for negative UnitPrice. Not present.

# %%
df.sort_values(by='UnitPrice', ascending=False).head(10)
# Out:
#         InvoiceNo StockCode                     Description  Quantity  \
# 120313     556444     22502  PICNIC BASKET WICKER 60 PIECES        60
# 120314     556446     22502  PICNIC BASKET WICKER 60 PIECES         1
# 110671     554836     22655     VINTAGE RED KITCHEN CABINET         1
# 69509      547814     22656    VINTAGE BLUE KITCHEN CABINET         1
# 40239      543253     22655     VINTAGE RED KITCHEN CABINET         1
# 61001      546480     22656    VINTAGE BLUE KITCHEN CABINET         1
# 90147      551393     22656    VINTAGE BLUE KITCHEN CABINET         1
# 25195      540647     22655     VINTAGE RED KITCHEN CABINET         1
# 2956       536835     22655     VINTAGE RED KITCHEN CABINET         1
# 17090      539080     22655     VINTAGE RED KITCHEN CABINET         1
#
#                 InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice
# 120313  2011-06-10 15:28:00      649.5     15098.0  United Kingdom     38970.0
# ...

# %% [markdown]
# Check for unusually high prices. Max price is 649.5 which is fine.

# %%
df['Country'].value_counts()
# Out:
# Country
# United Kingdom          267304
# Germany                   6527
# France                    6018
# EIRE                      5643
# Spain                     1917
# Netherlands               1686
# Belgium                   1440
# Switzerland               1372
# Portugal                  1086
# Australia                  943
# Norway                     813
# Italy                      629
# Channel Islands            616
# Cyprus                     522
# Finland                    470
# Austria                    300
# Denmark                    276
# Poland                     270
# Sweden                     266
# Japan                      220
# Israel                     174
# Singapore                  160
# Iceland                    139
# USA                        131
# Greece                     119
# Canada                     100
# Malta                       99
# RSA                         54
# United Arab Emirates        50
# European Community          49
# ...

# %%
df['InvoiceDate'].min(), df['InvoiceDate'].max()
# Out:
# ('2010-12-01 08:26:00', '2011-12-09 12:50:00')

# %%
df.groupby('CustomerID')['TotalPrice'].sum().sort_values(ascending=False).head(10)
# Out:
# CustomerID
# 18102.0    257518.90
# 14646.0    240080.31
# 17450.0    192076.59
# 16446.0    168472.50
# 14911.0    121882.00
# 12415.0    109984.21
# 14156.0    107403.59
# 17511.0     77796.46
# 12346.0     77183.60
# 16029.0     68196.09
# Name: TotalPrice, dtype: float64

# %%
df.describe(include='all')
# Out:
#             InvoiceNo StockCode                         Description  \
# count   299540.000000    299540                              299540
# unique            NaN      3046                                3227
# top               NaN    85123A  WHITE HANGING HEART T-LIGHT HOLDER
# freq              NaN      2023                                2016
# mean    560324.609842       NaN                                 NaN
# std      13159.629916       NaN                                 NaN
# min     536365.000000       NaN                                 NaN
# 25%     548712.000000       NaN                                 NaN
# 50%     561507.000000       NaN                                 NaN
# 75%     571883.000000       NaN                                 NaN
# max     581587.000000       NaN                                 NaN
#
#              Quantity          InvoiceDate      UnitPrice     CustomerID  \
# count   299540.000000               299540  299540.000000  299540.000000
# ...
